# %% [markdown]
# ## Functions

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
def greeting(name):
  print('Hello   '+ name + 'welcome to NDI training hub ')

# %% [markdown]
# parameter here is name... parameters are place holders for information and they are declared for python to know that the function will take in something but the user will determine what the name as a parameter will become when it is an argument.

# %%
greeting('Neto')
# Out:
# Hello   Netowelcome to NDI training hub

# %% [markdown]
# greeting was made a function with the code before this

# %%
def multiplyByThree(val):
    return 3 * val

multiplyByThree(4)
# Out:
# 12

# %% [markdown]
# What does return do? It saves whatever calculation it carries out.It keeps it somewhere..... Without return, it does not save what it caculates therefore it shows none.
#
# Therefore, a multiply function should not be run without the return function.

# %% [markdown]
# multiplyByThree is the function and val is the parameter which can be determined by the user when it becomes a parameter.

# %%
multiplyByThree(20)
# Out:
# 60

# %%
def multiply(val1, val2):
    return val1 * val2

# %% [markdown]
# Multiplies the two values guven to it

# %%
multiply(3, 4)
# Out:
# 12

# %%
a = [1,2,3]

def appendFour(myList):
    myList.append(4)

appendFour(a)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
my_list =[1,2,3]
appendFour(my_list)
print(my_list)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# This function will add the number 4 to any list

# %%
a= ['Neto', 'Miracle']
appendFour(a)
print(a)
# Out:
# ['Neto', 'Miracle', 4]

# %%
print(print('Hello, World!'))
# Out:
# Hello, World!
# None

# %%
type(None)
# Out:
# NoneType

# %%
None + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 None + 1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'
