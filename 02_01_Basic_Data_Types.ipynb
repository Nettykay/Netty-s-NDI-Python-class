# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Defining a Variable

# %%
x = 5
NAME = "Netochi"
Person_1 = "Philip"
Staff_id = "012345"

# %% [markdown]
# A variable is a box/container used to store any information.
# e.g X=5, X is the variable because it is storing the number 5
#
# NOTE: Python is case sensitive

# %%
name = 'Netochi'
print(name)
# Out:
# Netochi

# %% [markdown]
# name is the variable here and printing name always brings up Netochi which is the content of the variable ***name***

# %%
x
# Out:
# 5

# %%
name = 'Ryan'

# %%
type(name)
# Out:
# str

# %%
type(x)
# Out:
# int

# %% [markdown]
# ## Numbers

# %%
type(1.5)
# Out:
# float

# %%
1.23456789

# %%
12345678.9

# %%
type(2j)
# Out:
# complex

# %%
1j * 1j
# Out:
# (-1+0j)

# %% [markdown]
# ## Strings

# %%
'String 1 ' + 'String 2'
# Out:
# 'String 1 String 2'

# %%
'1' + '1'
# Out:
# '11'

# %%
'1' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 '1' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true = True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False
