# %% [markdown]
# # Title
# ## Smaller Title

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %%
print("having some data science!")
# Out:
# having some data science!

# %%
print(1 + 1)
# Out:
# 2

# %%
print('Doing some data science')
print('Netochi')
print('Hello world')
# Out:
# Doing some data science
# Netochi
# Hello world

# %%
print(20-24)
print('3+5')
# Out:
# -4
# 3+5
